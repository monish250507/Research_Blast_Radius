# %% [markdown]
# # Exploratory analysis

# %%
from src.preprocess import load_and_scale
import os

# %%
rows = load_and_scale('data/raw.csv')
print(len(rows))

# %%
df = rows

# %%
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot([1, 2, 3])
fig.savefig('figures/nb_plot.png')
